# %%
import pandas as pd
import numpy as np
import torch
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(1)

# %%
TRAINING_FILE = "/home/prohor/Workspace/pycharm_tmp/pycharm_project_597/storage/dataset/train.csv"
df = pd.read_csv(TRAINING_FILE)
df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# ...

# %%
# df = df[df['sentiment'] == 'positive']
# df = df[(df['sentiment'] == 'positive') | (df['sentiment'] == 'negative')]
df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# ...

# %%
df = df.sample(frac=1)
df
# Out:
#            textID                                               text  \
# 26804  6675f9536d  : Aww, that sux!  _x3: Eeek for Airline charge...
# 4172   7440e87ea2   O dear! HE`S HERE! OMGOGMGO.. U didn`t see th...
# 13782  7d64708739  Um. Why can`t I write **** tonight? I like ***...
# 18553  8c4a57dd60  Special mention for the new Mean Girl ... welc...
# 17264  2f42dff0dd        school for a bit. glad jake got the day off
# ...           ...                                                ...
# 10955  a77df4a95a  I`m still up! Thank you all for praying (: AHA...
# 17289  9d263a3553   Dude I feel really bad but it doesn`t work. I...
# 5192   b094214bd0  I like taking my dogs with me in the car when ...
# 12172  ab174bf51d  odd i tried to call mitchel musso but it dosen...
# 235    4bda359cbb  Done at the spa   now meeting vic for some lat...
#
#                                            selected_text sentiment
# 26804                                          that sux!  negative
# ...

# %%
len(df)
# Out:
# 27481

# %%
df.reset_index(inplace=True)
df.reset_index(inplace=True)

# %%
df
# Out:
#        level_0  index      textID  \
# 0            0  26804  6675f9536d
# 1            1   4172  7440e87ea2
# 2            2  13782  7d64708739
# 3            3  18553  8c4a57dd60
# 4            4  17264  2f42dff0dd
# ...        ...    ...         ...
# 27476    27476  10955  a77df4a95a
# 27477    27477  17289  9d263a3553
# 27478    27478   5192  b094214bd0
# 27479    27479  12172  ab174bf51d
# 27480    27480    235  4bda359cbb
#
#                                                     text  \
# 0      : Aww, that sux!  _x3: Eeek for Airline charge...
# 1       O dear! HE`S HERE! OMGOGMGO.. U didn`t see th...
# 2      Um. Why can`t I write **** tonight? I like ***...
# 3      Special mention for the new Mean Girl ... welc...
# 4            school for a bit. glad jake got the day off
# ...                                                  ...
# 27476  I`m still up! Thank you all for praying (: AHA...
# 27477   Dude I feel really bad but it doesn`t work. I...
# ...

# %%
df['kfold'] = df['level_0'].apply(lambda i: int(i * 5 / len(df)))

# %%
df
# Out:
#        level_0  index      textID  \
# 0            0  26804  6675f9536d
# 1            1   4172  7440e87ea2
# 2            2  13782  7d64708739
# 3            3  18553  8c4a57dd60
# 4            4  17264  2f42dff0dd
# ...        ...    ...         ...
# 27476    27476  10955  a77df4a95a
# 27477    27477  17289  9d263a3553
# 27478    27478   5192  b094214bd0
# 27479    27479  12172  ab174bf51d
# 27480    27480    235  4bda359cbb
#
#                                                     text  \
# 0      : Aww, that sux!  _x3: Eeek for Airline charge...
# 1       O dear! HE`S HERE! OMGOGMGO.. U didn`t see th...
# 2      Um. Why can`t I write **** tonight? I like ***...
# 3      Special mention for the new Mean Girl ... welc...
# 4            school for a bit. glad jake got the day off
# ...                                                  ...
# 27476  I`m still up! Thank you all for praying (: AHA...
# 27477   Dude I feel really bad but it doesn`t work. I...
# ...

# %%
del df['level_0']

# %%
del df['index']

# %%
#df.to_csv('/home/prohor/Workspace/pycharm_tmp/pycharm_project_597/storage/dataset/train_folds_pos_and_neg_no_prep.csv')
df.to_csv('/home/prohor/Workspace/pycharm_tmp/pycharm_project_597/storage/dataset/train_folds_no_prep.csv')
