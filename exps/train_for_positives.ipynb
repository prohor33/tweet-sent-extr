# %%
import pandas as pd
import numpy as np
import torch
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(1)

# %%
TRAINING_FILE = "/home/prohor/Workspace/pycharm_tmp/pycharm_project_597/storage/dataset/train.csv"
df = pd.read_csv(TRAINING_FILE)
df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# ...

# %%
df = df[df['sentiment'] == 'positive']
df
# Out:
#            textID                                               text  \
# 6      6e0c6d75b1  2am feedings for the baby are fun when he is a...
# 9      fc2cbefa9d   Journey!? Wow... u just became cooler.  hehe....
# 11     16fab9f95b  I really really like the song Love Story by Ta...
# 21     e48b0b8a23  Playing Ghost Online is really interesting. Th...
# 25     e00c6ef376  the free fillin` app on my ipod is fun, im add...
# ...           ...                                                ...
# 27467  432e6de6c9  morning twit-friends! welcome to my new followers
# 27474  8f14bb2715  So I get up early and I feel good about the da...
# 27475  b78ec00df5                                     enjoy ur night
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
#
#                                            selected_text sentiment
# 6                                                    fun  positive
# ...

# %%
df = df.sample(frac=1)
df
# Out:
#            textID                                               text  \
# 16064  a252d170ca                                  Goodmorning World
# 27149  d7f89cb7a4  If you save these pix from the Today show plea...
# 2595   4c45541bc8  Hey, thanks for the follow, wow this is exciti...
# 5199   3fcbbaf8a4   You`re not here. I hope you`re still resting....
# 25258  066cd71119  Today I wrote two songs (one for temple which ...
# ...           ...                                                ...
# 9163   80e0e88058    Great !!! Your book looks fantastic ? I want it
# 24782  ccadc7885d  heading out to dinner in a minute - cant wait ...
# 2809   d1c734c2c4                    ...Thank you Mr. President!....
# 16541  b38c364edc   i know ridiculous! we never got to hang out  ...
# 775    e350274c1a                         The World is just amazing!
#
#                                            selected_text sentiment
# 16064                                        Goodmorning  positive
# ...

# %%
df['fold'] = 1

# %%
len(df)
# Out:
# 8582

# %%
df.reset_index(inplace=True)
df.reset_index(inplace=True)

# %%
df
# Out:
#       level_0  index      textID  \
# 0           0  16064  a252d170ca
# 1           1  27149  d7f89cb7a4
# 2           2   2595  4c45541bc8
# 3           3   5199  3fcbbaf8a4
# 4           4  25258  066cd71119
# ...       ...    ...         ...
# 8577     8577   9163  80e0e88058
# 8578     8578  24782  ccadc7885d
# 8579     8579   2809  d1c734c2c4
# 8580     8580  16541  b38c364edc
# 8581     8581    775  e350274c1a
#
#                                                    text  \
# 0                                     Goodmorning World
# 1     If you save these pix from the Today show plea...
# 2     Hey, thanks for the follow, wow this is exciti...
# 3      You`re not here. I hope you`re still resting....
# 4     Today I wrote two songs (one for temple which ...
# ...                                                 ...
# 8577    Great !!! Your book looks fantastic ? I want it
# 8578  heading out to dinner in a minute - cant wait ...
# ...

# %%
df['kfold'] = df['level_0'].apply(lambda i: int(i * 5 / len(df)))

# %%
df
# Out:
#       level_0  index      textID  \
# 0           0  16064  a252d170ca
# 1           1  27149  d7f89cb7a4
# 2           2   2595  4c45541bc8
# 3           3   5199  3fcbbaf8a4
# 4           4  25258  066cd71119
# ...       ...    ...         ...
# 8577     8577   9163  80e0e88058
# 8578     8578  24782  ccadc7885d
# 8579     8579   2809  d1c734c2c4
# 8580     8580  16541  b38c364edc
# 8581     8581    775  e350274c1a
#
#                                                    text  \
# 0                                     Goodmorning World
# 1     If you save these pix from the Today show plea...
# 2     Hey, thanks for the follow, wow this is exciti...
# 3      You`re not here. I hope you`re still resting....
# 4     Today I wrote two songs (one for temple which ...
# ...                                                 ...
# 8577    Great !!! Your book looks fantastic ? I want it
# 8578  heading out to dinner in a minute - cant wait ...
# ...

# %%
del df['level_0']

# %%
del df['index']

# %%
df.to_csv('/home/prohor/Workspace/pycharm_tmp/pycharm_project_597/storage/dataset/positive_train_folds.csv')
