# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = [0.7013818535,
0.7041271015,
0.7023784475,
0.7034198605]

# %%
pp2 = plt.hist(data, bins=8)
plt.title("Estimated (Rounded) Mean Jaccard Scores")
plt.show()
