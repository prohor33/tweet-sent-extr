# %%
import pandas as pd

# %%
df = pd.read_csv('/home/prohor/Workspace/pycharm_tmp/pycharm_project_597/storage/runs_dbg/06_06_2020__21_48_57_roberta-base-1.6_4119/calculate_jaccard_score_0.log')

# %%
df
# Out:
#                                     target_string_strip  \
# 0                         graduates college on saturday
# 1                                                thanks
# 2     how come when i straighten my hair it has to s...
# 3                                               Enjoyed
# 4                                                  ****
# ...                                                 ...
# 5492                  Holy cow, am I getting shorter?!?
# 5493                                          rubbish..
# 5494                                              dead?
# 5495                   why the hell is air not on TODAY
# 5496                                                bad
#
#                                   filtered_output_strip       jac  \
# 0                         graduates college on saturday  1.000000
# 1                                                thanks  1.000000
# 2     how come when i straighten my hair it has to s...  1.000000
# ...
